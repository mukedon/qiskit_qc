# %% [markdown]
# <a href="https://colab.research.google.com/github/mukedon/quantum_computing/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
asd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8667/3279299088.py in <cell line: 0>()
# ----> 1 asd
#
# NameError: name 'asd' is not defined
